# %% [markdown]
# ### Python Data-science Introduction- Web Scrapping
# Web scraping (also called web data extraction or data scraping) provides a solution for those who want to get access to structured web data in an automated fashion.
# Web scraping is useful if the public website you want to get data from doesn't have an API, or it does but provides only limited access to the data.
# Hence:-
# - I scrapped data from the Zimbabwe Stock Exchange
# - Scrapped Emails from the same
# - Scrapped images from the same website
# - Scrapped tables from the World population Wikipedia webpage and converted it into a dataframe.
# - Used pandas (pd.read.html) to scrap data from a table @'https://www.zse.co.zw/price-sheet' website.
# - Cleaned the data although it had a lot of discrepencies
# - Saved the new data set into my local library

# %%
#!pip install bs4
#!pip install lxml==4.6.4
#!pip install requests==2.26.0
#!pip install html5lib==1.1 -y

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup # this is a webscrapping module
import requests # requests module helps us to download a web page

# %% [markdown]
# This project is to show how we can download data from a web page.
# iam going to scrap data from the Zimbabwe stock exchange page and store it into a data frame

# %% [markdown]
# ### Data source -zimbabwe stock exchange 25/10/22
#
# We have to download the data from the web page and store it inside a web page called ZSE_data:

# %%
url='https://www.zse.co.zw/price-sheet'

# %%
ZSE_data=requests.get(url).text

# %%
# We create a BeautifulSoup object(soup) using a BS constructor

soup=BeautifulSoup(ZSE,'html.parser')

# %% [markdown]
# #### 1.  Scraping all links

# %%
# in html anchor/link is represented by the tag <a>
for link in soup.find_all('a',href=True): 
    
    print(link.get('href'))
# Out:
# https://www.zse.co.zw/
# https://www.zse.co.zw/
# https://www.zse.co.zw/rules-and-regulations/
# https://www.zse.co.zw/faqs/
# https://www.zse.co.zw/fungibility-faqs-2/
# https://www.zse.co.zw/practice-and-procedures/
# https://www.zse.co.zw/rules-legislation/
# https://www.zse.co.zw/companies-2/
# https://www.zse.co.zw/equity/
# https://www.zse.co.zw/abc/
# https://www.zse.co.zw/african-distillers-limited-2/
# https://www.zse.co.zw/african-sun-limited-2/
# https://www.zse.co.zw/amalgamated-regional-trading-art-holdings-limited-2/
# https://www.zse.co.zw/ariston-holdings-limited-2/
# https://www.zse.co.zw/axia-corporation-limited-2/
# https://www.zse.co.zw/bindura-nickel-corporation-limited-2/
# https://www.zse.co.zw/border-timbers-limited/
# https://www.zse.co.zw/british-american-tobacco-zimbabwe-limited-2/
# https://www.zse.co.zw/cafca-limited-2/
# https://www.zse.co.zw/cbz-holdings-limited-2/
# https://www.zse.co.zw/cfi-holdings-limited-2/
# https://www.zse.co.zw/cottco-holdings-limited-2/
# https://www.zse.co.zw/def/
# https://www.zse.co.zw/dairibord-holdings-limited-2/
# https://www.zse.co.zw/delta-corporation-limited-2/
# https://www.zse.co.zw/ecocash-holdings/
# https://www.zse.co.zw/econet-wireless-zimbabwe-limited-2/
# https://www.zse.co.zw/edgars-stores-limited-2/
# https://www.zse.co.zw/fbc-holdings-limited-2/
# https://www.zse.co.zw/fidelity-life-assurance-limited-2/
# https://www.zse.co.zw/first-capital-bank-limited-2/
# https://www.zse.co.zw/first-mutual-holdings-limited-2/
# https://www.zse.co.zw/first-mutual-properties-2/
# https://www.zse.co.zw/ghijklm/
# https://www.zse.co.zw/general-beltings-holdings-limited-2/
# https://www.zse.co.zw/getbucks-microfinance-bank-limited-2/
# https://www.zse.co.zw/hippo-valley-estates-limited-2/
# https://www.zse.co.zw/hwange-colliery-company-limited/
# https://www.zse.co.zw/innscor-africa-limited-2/
# https://www.zse.co.zw/lafarge-cement-zimbabwe-limited-2/
# https://www.zse.co.zw/mashonaland-holdings-limited/
# https://www.zse.co.zw/masimba-holdings-limited-2/
# https://www.zse.co.zw/medtech-holdings-limited-2/
# https://www.zse.co.zw/meikles-limited-2/
# https://www.zse.co.zw/nop/
# https://www.zse.co.zw/nampak-zimbabwe-limited-2/
# https://www.zse.co.zw/national-foods-holdings-limited/
# https://www.zse.co.zw/national-tyre-services-limited-2/
# https://www.zse.co.zw/nmbz-holdings-limited-2/
# https://www.zse.co.zw/ok-zimbabwe-limited-2/
# https://www.zse.co.zw/old-mutual-limited-2/
# https://www.zse.co.zw/pretoria-portland-cement-limited-2/
# https://www.zse.co.zw/proplastics-limited-2/
# https://www.zse.co.zw/rstuvw/
# https://www.zse.co.zw/rainbow-tourism-group-limited-2/
# https://www.zse.co.zw/riozim-limited-2/
# https://www.zse.co.zw/seed-co-limited-2/
# https://www.zse.co.zw/simbisa-brands-limited-2/
# https://www.zse.co.zw/starafricacorporation-limited-2/
# https://www.zse.co.zw/tanganda-limited/
# https://www.zse.co.zw/truworths-limited-2/
# https://www.zse.co.zw/tsl-limited-2/
# https://www.zse.co.zw/turnall-holdings-limited-2/
# https://www.zse.co.zw/unifreight-africa-limited-2/
# https://www.zse.co.zw/willdale-limited-2/
# https://www.zse.co.zw/xyz/
# https://www.zse.co.zw/zb-financial-holdings-limited/
# https://www.zse.co.zw/zeco-holdings-limited-2/
# https://www.zse.co.zw/zimbabwe-newspapers-1980-limited-2/
# https://www.zse.co.zw/zimplow-holdings-limited-2/
# https://www.zse.co.zw/zimre-holdings-limited-2/
# https://www.zse.co.zw/etf/
# https://www.zse.co.zw/members/
# https://www.zse.co.zw/market-makers/
# https://www.zse.co.zw/akribos-securities-pvt-limited/
# https://www.zse.co.zw/datvest-modified-consumer-staples-etf/
# https://www.zse.co.zw/old-mutual-securities-pvt-limited/
# https://www.zse.co.zw/old-mutual-zse-top-ten-etf/
# https://www.zse.co.zw/morgan-and-company-pvt-limited/
# https://www.zse.co.zw/old-mutual-zse-top-ten-etf/
# https://www.zse.co.zw/morgan-co-multi-sector-etf/
# https://www.zse.co.zw/non-member-institutions/
# https://www.zse.co.zw/stock-brokers/
# https://www.zse.co.zw/abcde/
# https://www.zse.co.zw/abc-stockbrokers-pvt-limited/
# https://www.zse.co.zw/bethel-equities-pvt-limited/
# https://www.zse.co.zw/akribos-securities-pvt-limited/
# https://www.zse.co.zw/efe-securities-pvt-limited/
# https://www.zse.co.zw/fghi/
# https://www.zse.co.zw/fbc-securities-pvt-limited/
# https://www.zse.co.zw/fincent-securities-private-limited/
# https://www.zse.co.zw/ingeniumcapital-pvt-limited/
# https://www.zse.co.zw/imara-edwards-securities-pvt-limited/
# https://www.zse.co.zw/interhorizon-securities-pvt-limited/
# https://www.zse.co.zw/invictus-securities-pvt-limited/
# https://www.zse.co.zw/jklmno/
# https://www.zse.co.zw/jemina-capital-pvt-limited/
# https://www.zse.co.zw/lynton-edwards-stockbrokers-pvt-limited/
# https://www.zse.co.zw/mast-stockbrokers-pvt-limited/
# https://www.zse.co.zw/mmc-capital-pvt-limited/
# https://www.zse.co.zw/morgan-and-company-pvt-limited/
# https://www.zse.co.zw/old-mutual-securities-pvt-limited/
# https://www.zse.co.zw/pqrs/
# https://www.zse.co.zw/platinum-securities-pvt-limited/
# https://www.zse.co.zw/remo-investment-brokers-pvt-limited/
# https://www.zse.co.zw/southern-trust-securities-pvt-limited/
# https://www.zse.co.zw/wealthaccess-securities-pvt-limited-copy/
# https://www.zse.co.zw/market-statistics-copy/
# https://www.zse.co.zw/market-statistics/
# https://www.zse.co.zw/price-sheet/
# https://www.zse.co.zw/market-commentary-archive/
# https://www.zse.co.zw/weekly-report-archive/
# https://www.zse.co.zw/indices/
# https://www.zse.co.zw/tsi/
# http://zsetraining.co.zw/
# https://www.zse.co.zw/zse-depository/
# https://www.zse.co.zw/depository-services/
# https://www.zse.co.zw/clearing-settlement-services/
# https://www.zse.co.zw/risk-management/
# https://www.zse.co.zw/fees/
# https://www.zse.co.zw/wp-content/uploads/2021/09/ZIMBABWE-STOCK-EXCHANGE-DEPOSITORY-PROCEDURE-MANUAL-Final.pdf
# https://www.zse.co.zw/depository-faqs/
# https://www.zse.co.zw/wp-content/uploads/2021/09/ZIMBABWE-STOCK-EXCHANGE-DEPOSITORY-CSD-RULES.pdf
# https://www.zse.co.zw/forms/
# https://www.zse.co.zw/about-us/
# https://www.zse.co.zw/about-us/
# https://www.zse.co.zw/board-of-directors/
# https://www.zse.co.zw/board-committees-2/
# https://www.zse.co.zw/executive-management-2/
# https://www.zse.co.zw/annual-reports/
# https://www.zse.co.zw/careers/
# https://www.zse.co.zw/contacts-2/
# https://www.zse.co.zw/scholarships/
# https://www.zse.co.zw/zsenotices/
# https://www.zse.co.zw
# https://twitter.com/ZSE_ZW
# https://twitter.com/ZSE_ZW
# https://twitter.com/ZSE_ZW
# https://twitter.com/ZSE_ZW
# https://twitter.com/ZSE_ZW/status/1585557544440930306
# https://twitter.com/ZSE_ZW/status/1585557544440930306
# https://twitter.com/intent/tweet?in_reply_to=1585557544440930306&related=ZSE_ZW
# https://twitter.com/intent/retweet?tweet_id=1585557544440930306&related=ZSE_ZW
# https://twitter.com/intent/like?tweet_id=1585557544440930306&related=ZSE_ZW
# https://twitter.com/ZSE_ZW/status/1585557544440930306
# javascript:void(0);
# https://www.zse.co.zw/wp-content/uploads/2019/12/ZSE-Investors-Guide.pdf
# https://www.zse.co.zw/wp-content/uploads/2019/06/S.I.-134-of-2019-Security-Exchange-.pdf
#  http://www.zse.co.zw/market-statistics/
# https://www.zse.co.zw/rules-and-regulations/
# https://www.zse.co.zw/companies/
# https://www.zse.co.zw/wp-content/uploads/2019/06/S.I.-134-of-2019-Security-Exchange-.pdf
# https://www.zse.co.zw/stock-brokers/
# https://www.zse.co.zw/contacts-2/
# http://www.seczim.co.zw/
# https://www.rbz.co.zw/
# http://www.zim.gov.zw/government-ministries/ministry-finance-and-economic-development
# http://www.chengetedzai.co.zw/
# https://www.facebook.com/Zimstockexchange/
# https://twitter.com/ZSE_ZW
# https://www.linkedin.com/company/zimbabwestockexchange/
# #

# %% [markdown]
# #### 2. Scraping all images

# %%
# in html image is represented by the tag <img>
for link in soup.find_all('img'):
    print(link)
    print(link.get('src'))
# Out:
# <img class="img-responsive" src="https://www.zse.co.zw/wp-content/uploads/2019/03/logo.png" style="height:75px; width:150px;"/>
# https://www.zse.co.zw/wp-content/uploads/2019/03/logo.png
# <img alt="Webp.net-gifmaker" class="fl-photo-img wp-image-2306" itemprop="image" src="https://www.zse.co.zw/wp-content/uploads/2019/03/Webp.net-gifmaker-1.gif" title="Webp.net-gifmaker"/>
# https://www.zse.co.zw/wp-content/uploads/2019/03/Webp.net-gifmaker-1.gif
# <img alt="Zimbabwe Stock Exchange" height="48" src="https://pbs.twimg.com/profile_images/1018818881023070209/jvwXgyQD_normal.jpg" width="48"/>
# https://pbs.twimg.com/profile_images/1018818881023070209/jvwXgyQD_normal.jpg
# <img alt="ZSE_ZW" height="48" src="https://pbs.twimg.com/profile_images/1018818881023070209/jvwXgyQD_normal.jpg" width="48"/>
# https://pbs.twimg.com/profile_images/1018818881023070209/jvwXgyQD_normal.jpg

# %% [markdown]
# #### 3. Scraping data from HTML tables
#
# Its important that before scrapping data from a website.There is a need to examine the contents,and the ays data is organised on the website.

# %%
# Get the contents of the webpage in text format and store in a variable called ZSE_data
ZSE_data = requests.get(url).text

soup=BeautifulSoup(ZSE_data,'html.parser')

# %%
# Finding a html table in the web page
# in html table is represented by the tag<table>

table=soup.find('table')

# %%
# Getting all rows from the table
# in html a column is represented by the tag <td>
for row in table.find_all('tr'):
    cols=row.find_all('td')
    color_name=cols[2].string   # storing the value in column 3 as color name
    color_code= cols[3].string  # store the value in the column 4 as color_code
    print('{}--->{}'.format(color_name,color_code))
# Out:
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->298
# None--->None
# None--->None
# None--->None
# 15.05--->8200
# None--->None
# None--->None
# None--->4.2
# None--->None
# None--->64.6379
# None--->None
# None--->7.1
# None--->None
# 26--->26
# None--->None
# 2995.975--->0
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->49.7158
# None--->None
# None--->230.191
# None--->None
# 45.7564--->45.6504
# None--->None
# 84.6252--->84.8125
# None--->None
# None--->7.47
# None--->None
# None--->None
# None--->None
# None--->22
# None--->None
# None--->9.3992
# None--->None
# None--->25.8002
# None--->None
# None--->9.04
# None--->None
# 2--->2
# None--->None
# 17.55--->17.55
# None--->None
# None--->207.7526
# None--->None
# None--->310.6556
# None--->None
# 120--->120
# None--->None
# None--->7.5
# None--->None
# None--->75
# None--->None
# None--->None
# None--->None
# None--->8.7
# None--->None
# None--->1105
# None--->None
# None--->12
# None--->None
# None--->21.7667
# None--->None
# None--->32.8486
# None--->None
# None--->None
# None--->7.64
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->227.2115
# None--->None
# None--->1.6987
# None--->None
# 84--->81
# None--->None
# None--->None
# None--->None
# None--->None
# None--->None
# None--->3.91
# None--->None
# None--->52.9692
# None--->None
# None--->None
# None--->None
# None--->115.011
# None--->None
# None--->0.0331
# None--->None
# 3--->3
# None--->None
# None--->16
# None--->None
# None--->5.1

# %% [markdown]
# #### 4. Scrapping data from HTML tables into a DataFrame
#       (pandas/Beautiful soup)

# %%
url = "https://en.wikipedia.org/wiki/World_population"
ppn =requests.get(url).text
soup=BeautifulSoup(ppn,'html.parser')
tables= soup.find_all('table')

# %%
# to check how many tables were found by checking of the tables list

len(tables)
# Out:
# 25

# %%
for index,table in enumerate(tables):
    if ('10 most densely populated countries' in str(table)):
        table_index = index
print(table_index)
# Out:
# 5

# %%
print(tables[table_index].prettify())
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <caption>
#   10 most densely populated countries
#   <small>
#    (with population above 5 million)
#   </small>
#  </caption>
#  <tbody>
#   <tr>
#    <th>
#     Rank
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Population
#    </th>
#    <th>
#     Area
#     <br/>
#     <small>
#      (km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#    <th>
#     Density
#     <br/>
#     <small>
#      (pop/km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/23px-Flag_of_Singapore.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/35px-Flag_of_Singapore.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/45px-Flag_of_Singapore.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Singapore" title="Singapore">
#      Singapore
#     </a>
#    </td>
#    <td>
#     5,704,000
#    </td>
#    <td>
#     710
#    </td>
#    <td>
#     8,033
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/23px-Flag_of_Bangladesh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/35px-Flag_of_Bangladesh.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/46px-Flag_of_Bangladesh.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Bangladesh" title="Bangladesh">
#      Bangladesh
#     </a>
#    </td>
#    <td>
#     173,640,000
#    </td>
#    <td>
#     143,998
#    </td>
#    <td>
#     1,206
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td align="left">
#     <p>
#      <span class="flagicon">
#       <img alt="" class="thumbborder" data-file-height="216" data-file-width="432" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/23px-Flag_of_Palestine.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/35px-Flag_of_Palestine.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/46px-Flag_of_Palestine.svg.png 2x" width="23"/>
#      </span>
#      <a href="/wiki/State_of_Palestine" title="State of Palestine">
#       Palestine
#      </a>
#     </p>
#    </td>
#    <td>
#     5,266,785
#    </td>
#    <td>
#     6,020
#    </td>
#    <td>
#     847
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/23px-Flag_of_Lebanon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/35px-Flag_of_Lebanon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/45px-Flag_of_Lebanon.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Lebanon" title="Lebanon">
#      Lebanon
#     </a>
#    </td>
#    <td>
#     6,856,000
#    </td>
#    <td>
#     10,452
#    </td>
#    <td>
#     656
#    </td>
#   </tr>
#   <tr>
#    <td>
#     5
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/23px-Flag_of_the_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/35px-Flag_of_the_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/45px-Flag_of_the_Republic_of_China.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Taiwan" title="Taiwan">
#      Taiwan
#     </a>
#    </td>
#    <td>
#     23,604,000
#    </td>
#    <td>
#     36,193
#    </td>
#    <td>
#     652
#    </td>
#   </tr>
#   <tr>
#    <td>
#     6
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/South_Korea" title="South Korea">
#      South Korea
#     </a>
#    </td>
#    <td>
#     51,781,000
#    </td>
#    <td>
#     99,538
#    </td>
#    <td>
#     520
#    </td>
#   </tr>
#   <tr>
#    <td>
#     7
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="720" data-file-width="1080" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/23px-Flag_of_Rwanda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/35px-Flag_of_Rwanda.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/45px-Flag_of_Rwanda.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Rwanda" title="Rwanda">
#      Rwanda
#     </a>
#    </td>
#    <td>
#     12,374,000
#    </td>
#    <td>
#     26,338
#    </td>
#    <td>
#     470
#    </td>
#   </tr>
#   <tr>
#    <td>
#     8
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="800" data-file-width="1100" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/21px-Flag_of_Israel.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/32px-Flag_of_Israel.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/41px-Flag_of_Israel.svg.png 2x" width="21"/>
#     </span>
#     <a href="/wiki/Israel" title="Israel">
#      Israel
#     </a>
#    </td>
#    <td>
#     9,600,000
#    </td>
#    <td>
#     22,072
#    </td>
#    <td>
#     435
#    </td>
#   </tr>
#   <tr>
#    <td>
#     9
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/23px-Flag_of_Haiti.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/35px-Flag_of_Haiti.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/46px-Flag_of_Haiti.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Haiti" title="Haiti">
#      Haiti
#     </a>
#    </td>
#    <td>
#     11,578,000
#    </td>
#    <td>
#     27,065
#    </td>
#    <td>
#     428
#    </td>
#   </tr>
#   <tr>
#    <td>
#     10
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/23px-Flag_of_the_Netherlands.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/35px-Flag_of_the_Netherlands.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/45px-Flag_of_the_Netherlands.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Netherlands" title="Netherlands">
#      Netherlands
#     </a>
#    </td>
#    <td>
#     17,760,000
#    </td>
#    <td>
#     41,526
#    </td>
#    <td>
#     428
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
population_data = pd.DataFrame(columns=["Rank", "Country", "Population", "Area", "Density"])

for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        rank = col[0].text
        country = col[1].text
        population = col[2].text.strip()
        area = col[3].text.strip()
        density = col[4].text.strip()
        population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)

population_data
# Out:
#   Rank           Country   Population     Area Density
# 0    1         Singapore    5,704,000      710   8,033
# 1    2        Bangladesh  173,640,000  143,998   1,206
# 2    3  \n Palestine\n\n    5,266,785    6,020     847
# 3    4           Lebanon    6,856,000   10,452     656
# 4    5            Taiwan   23,604,000   36,193     652
# 5    6       South Korea   51,781,000   99,538     520
# 6    7            Rwanda   12,374,000   26,338     470
# 7    8            Israel    9,600,000   22,072     435
# 8    9             Haiti   11,578,000   27,065     428
# 9   10       Netherlands   17,760,000   41,526     428

# %% [markdown]
# #### Scrape data from HTML tables into a DataFrame using BeautifulSoup and read_html
#
# Using the same url, data, soup, and tables object as in the last section we can use the read_html function to create a DataFrame.
# Function read_html always returns a list of DataFrames

# %%
pd.read_html(str(tables[5]), flavor='bs4')
# Out:
# [   Rank      Country  Population  Area(km2)  Density(pop/km2)
#  0     1    Singapore     5704000        710              8033
#  1     2   Bangladesh   173640000     143998              1206
#  2     3    Palestine     5266785       6020               847
#  3     4      Lebanon     6856000      10452               656
#  4     5       Taiwan    23604000      36193               652
#  5     6  South Korea    51781000      99538               520
#  6     7       Rwanda    12374000      26338               470
#  7     8       Israel     9600000      22072               435
#  8     9        Haiti    11578000      27065               428
#  9    10  Netherlands    17760000      41526               428]

# %%
population_data_read_html = pd.read_html(str(tables[5]), flavor='bs4')[0]

population_data_read_html
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   173640000     143998              1206
# 2     3    Palestine     5266785       6020               847
# 3     4      Lebanon     6856000      10452               656
# 4     5       Taiwan    23604000      36193               652
# 5     6  South Korea    51781000      99538               520
# 6     7       Rwanda    12374000      26338               470
# 7     8       Israel     9600000      22072               435
# 8     9        Haiti    11578000      27065               428
# 9    10  Netherlands    17760000      41526               428

# %% [markdown]
# #### Scrape data from HTML tables into a DataFrame using read_html
# - I used pd.read_html  to scrape Zimbabwe Stock exchange table from the Zimbabwe Stock Exchange.
# - I converted it into a list then had to convert the list into a data Frame.

# %%
urls='https://www.zse.co.zw/price-sheet'
dataframe_list = pd.read_html(urls, flavor='bs4')

# %%
len(dataframe_list)
# Out:
# 1

# %%
dataframe_list[0]
# Out:
#                                       0                                   1  \
# 0                          Company Name                        Company Name
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                              EQUITIES                            EQUITIES
# ..                                  ...                                 ...
# 103  Zimbabwe Newspapers (1980) Limited  Zimbabwe Newspapers (1980) Limited
# 104                                 NaN                                 NaN
# 105            Zimplow Holdings Limited            Zimplow Holdings Limited
# 106                                 NaN                                 NaN
# 107              Zimre Holdings Limited              Zimre Holdings Limited
#
#                                       2                                   3  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ..                                  ...                                 ...
# 103  Zimbabwe Newspapers (1980) Limited  Zimbabwe Newspapers (1980) Limited
# 104                                 NaN                                 NaN
# 105            Zimplow Holdings Limited                                 NaN
# 106                                 NaN                                 NaN
# 107              Zimre Holdings Limited                                 NaN
#
#        4              5              6                    7
# 0    NaN  Opening Price  Closing Price  Total Traded Volume
# 1    NaN            NaN            NaN                  NaN
# 2    NaN            NaN            NaN                  NaN
# 3    NaN            NaN            NaN                  NaN
# 4    NaN            NaN            NaN                  NaN
# ..   ...            ...            ...                  ...
# 103  NaN              3              3                49100
# 104  NaN            NaN            NaN                  NaN
# 105  NaN             16           17.8                  300
# 106  NaN            NaN            NaN                  NaN
# 107  NaN            5.1            5.1                 5900
#
# [108 rows x 8 columns]

# %% [markdown]
# #### Converting Data list into a data frame

# %%
ZSE_df = pd.DataFrame (dataframe_list[0])
print (ZSE_df)
# Out:
#                                       0                                   1  \
# 0                          Company Name                        Company Name
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                              EQUITIES                            EQUITIES
# ..                                  ...                                 ...
# 103  Zimbabwe Newspapers (1980) Limited  Zimbabwe Newspapers (1980) Limited
# 104                                 NaN                                 NaN
# 105            Zimplow Holdings Limited            Zimplow Holdings Limited
# 106                                 NaN                                 NaN
# 107              Zimre Holdings Limited              Zimre Holdings Limited
#
#                                       2                                   3  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ..                                  ...                                 ...
# 103  Zimbabwe Newspapers (1980) Limited  Zimbabwe Newspapers (1980) Limited
# 104                                 NaN                                 NaN
# 105            Zimplow Holdings Limited                                 NaN
# 106                                 NaN                                 NaN
# 107              Zimre Holdings Limited                                 NaN
#
#        4              5              6                    7
# 0    NaN  Opening Price  Closing Price  Total Traded Volume
# 1    NaN            NaN            NaN                  NaN
# 2    NaN            NaN            NaN                  NaN
# 3    NaN            NaN            NaN                  NaN
# 4    NaN            NaN            NaN                  NaN
# ..   ...            ...            ...                  ...
# 103  NaN              3              3                49100
# 104  NaN            NaN            NaN                  NaN
# 105  NaN             16           17.8                  300
# 106  NaN            NaN            NaN                  NaN
# 107  NaN            5.1            5.1                 5900
#
# [108 rows x 8 columns]

# %%
#dropping rows with null values

ZSE_data=ZSE_df.dropna()

# %%
ZSE_data
# Out:
#                                                     0  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     1  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     2  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     3  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     4         5         6  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...      17.6     15.05
# 21          British American Tobacco Zimbabwe Limited  2995.975  2995.975
#
#        7
# 10  8200
# 21     0

# %%
ZSE_data.describe()
# Out:
#                                                         0  \
# count                                                   2
# unique                                                  2
# top     Amalgamated Regional Trading (Art) Holdings Li...
# freq                                                    1
#
#                                                         1  \
# count                                                   2
# unique                                                  2
# top     Amalgamated Regional Trading (Art) Holdings Li...
# freq                                                    1
#
#                                                         2  \
# count                                                   2
# unique                                                  2
# top     Amalgamated Regional Trading (Art) Holdings Li...
# freq                                                    1
#
#                                                         3  \
# count                                                   2
# unique                                                  2
# top     Amalgamated Regional Trading (Art) Holdings Li...
# freq                                                    1
#
#                                                         4     5      6     7
# count                                                   2     2      2     2
# unique                                                  2     2      2     2
# top     Amalgamated Regional Trading (Art) Holdings Li...  17.6  15.05  8200
# freq                                                    1     1      1     1

# %% [markdown]
# #### Saving the dataframe into a file

# %%
ZSE_data.to_csv('Zimbabwe_Exchange_27_10_22',index=False)

# %%
ZSE_data.tail(10)
# Out:
#                                                     0  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     1  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     2  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     3  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...
# 21          British American Tobacco Zimbabwe Limited
#
#                                                     4         5         6  \
# 10  Amalgamated Regional Trading (Art) Holdings Li...      17.6     15.05
# 21          British American Tobacco Zimbabwe Limited  2995.975  2995.975
#
#        7
# 10  8200
# 21     0
