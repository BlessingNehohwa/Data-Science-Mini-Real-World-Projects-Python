# %% [markdown]
# # Data Science Basic Analysis- House Sales in King County, USA

# %% [markdown]
# This analyis is based on the King County Seattle House Sales
# Its a dataset of homes sold between May 2014 - May 2015

# %% [markdown]
# ### Load libraries

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# ### Importing Data Sets

# %%
file_name='C:/Users/beemu/Downloads/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# The datasets has 21613 rows and 22 columns
df.shape
# Out:
# (21613, 22)

# %%
### Dipslaying the data types of each column
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Getting the Statistical summary of the dataframe
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# ### Data Wrangling /Data Cleaning
# We need to clean the data set by dropping unnecesaary columns in the dataset
# namely "id" and "Unnamed:0"

# %%
df.drop(['Unnamed: 0','id'],axis=1,inplace=True)
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# There is need to also check for columns with missing values in the data sets we realise that 'bedrooms' and 'bathrooms' have missing values.
# Had to replace the columns missing value with the column mean values.
# - We use the bedrooms mean to fill all the bedroom missing values
# - We use the bathrooms mean to fill all the bathrooms missing values

# %%
# Checking the columns with missing values

df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %%
# Replacing the missing values
mean=df['bathrooms'].mean()
df['bathrooms'].replace(np.nan,mean,inplace=True)

mean=df['bedrooms'].mean()
df['bedrooms'].replace(np.nan,mean,inplace=True)

print(df['bedrooms'].isnull().sum())
print(df['bathrooms'].isnull().sum())
# Out:
# 0
# 0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Counting the number of houses with unique foor values and use .to_frame() 
# to convert it to a dataframe.

df['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
plt.figure (figsize = (20,7))
sns.boxplot(data = df, x="bedrooms", y = "price")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# Determining whether houses with a waterfront view or without a waterfront view have a more price outliers.
# Using <code>boxplot<code>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %% [markdown]
# Using regplot to determine if the feature rom the seaborn library sqft_above  is negatively or positively correlated with price.

# %%
sns.regplot(x='sqft_above', y='price', data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
plt.figure (figsize = (12,7))
sns.heatmap(df.corr(), vmin= -1, vmax= 1, cmap="Spectral", annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We need to find out the feature other than price that is most correlated to price.
# - sqrt_above,grade,sqft_living are the most correlated feature to price of houses

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Model Development
#
# We need to fit the linear regression model using the longitude feature 'long' and calculate the R^2.
# R-squared (Coefficient of Determination)is a goodness-of-fit measure for linear regression models.
# This statistic indicates the percentage of the variance in the dependent variable that the independent variables explain collectively.
# R-squared measures the strength of the relationship between your model and the dependent variable on a convenient 0 – 100% scale

# %%
X=df[['long']]
Y=df['price']
lm=LinearRegression()
lm.fit(X,Y)
lm.score(X,Y)
# Out:
# 0.00046769430149007363

# %%
x=df[['sqft_living']]
y=df['price']
lm=LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# The regression model has R^2 is , 49% changes in price is determined by sqrt_living
# the model is a great fit
# Out:
# 0.4928532179037931

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]     
x1=df[features]
y1=df['price']
lm=LinearRegression()
lm.fit(x1,y1)
lm.score(x1,y1)
# Out:
# 0.6576951666037502

# %% [markdown]
# Create a list of tuples, the first element in the tuple contains the name of the estimator:
#
# 'scale'
# 'polynomial'
# 'model'
#
# The second element in the tuple contains the model constructor
#
# StandardScaler()
# PolynomialFeatures(include_bias=False)
# LinearRegression()
#
# - I need to create a pipeline object to predict the 'price' fit the object using the features in the list features, and calculate the r^2

# %%
Input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
pipe.fit(X,Y)
pipe.score(X,Y)
# Out:
# 0.003360798516638175

# %% [markdown]
# ### Model Evaluation and Refinement
#
# Splitting data into training and testing sets

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### training and testing sets

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = df[features]
Y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)


print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples: 3242
# number of training samples: 18371

# %% [markdown]
# Ridge regression object using the training data, set the regularization parameter to 0.1, and calculate the R^2 using the test data.
# A second order polynomial transform on both the training data and testing data.
# Create and fit a Ridge regression object using the training data, set the regularisation parameter to 0.1, and calculate the R^2 utilising the test data provided

# %%
from sklearn.linear_model import Ridge 
RigeModel = Ridge(alpha=0.1) 
RigeModel.fit(x_train, y_train)
RigeModel.score(x_test, y_test)
# Out:
# 0.6478759163939112

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[features])
x_test_pr=pr.fit_transform(x_test[features])

RigeModel = Ridge(alpha=0.1) 
RigeModel.fit(x_train_pr, y_train)
RigeModel.score(x_test_pr, y_test)
# Out:
# 0.7002744259992868

# %% [markdown]
# ### Model, predict and solve
#
# Now we are ready to train a model and predict the required solution. There are 60+ predictive modelling algorithms to choose from. We must understand the type of problem and solution requirement to narrow down to a select few models which we can evaluate. Our problem is a classification and regression problem. We want to identify relationship between output (Survived or not) with other variables or features (Gender, Age, Port...). We are also perfoming a category of machine learning which is called supervised learning as we are training our model with a given dataset. With these two criteria - Supervised Learning plus Classification and Regression, we can narrow down our choice of models to a few. These include:
#
# - Logistic Regression
# - KNN or k-Nearest Neighbors
# - Support Vector Machines
# - Naive Bayes classifier
# - Decision Tree
# - Random Forrest
# - Perceptron
# - Artificial neural network
# - RVM or Relevance Vector Machine

# %% [markdown]
# ### Map - latitude and longitude

# %%
plt.figure(figsize= (15,7))
plt.title("Price of houses by latitude and longitude")
sns.scatterplot(data = df, x= "long", y = "lat", hue="price", palette="RdYlGn")
plt.show()
